# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn; seaborn.set()
import xlrd
import pandas as pd

# %%
Ngaundere2=pd.read_excel("6 months data for MPCModified (copy).xlsx",sheetname="Ngaundere2")
Ngaundere2.isnull().sum()
# Out:
# Cluster                               0
# T number                              0
# IHS ID                                0
# Site Name                             0
# GE N°                                 0
# NUMERO DE TICKET D'ACCES AU SITE      0
# DATE  EFFECTIVE DE LA VISITE          0
# DATE DE VISITE PRECEDENTE             0
# NBRE DE JOUR                          0
# TYPE DE GROUPE                        0
# Generator 1capacity (KVA)             0
# COMPTEUR HORAIRE ACTUEL GE1           0
# ANCIEN COMPTEUR HORAIRE G1            0
# SERVICE (YES/NO)                    225
# OIL REMOVED                         223
# OIL ADDED                           223
# GEN 1\nAIR FILTER\nReferences       260
# GEN 1\nOIL FILTER\nReferences       236
# GEN 1\nFUEL FILTER\nReferences      231
# GEN 1\nFAN BELT\nReferences         258
# QTEFUELPRECEDENTE                    17
# QTEFUELTROUVEE                       17
# QTEFUELAJOUTEE                       17
# ...

# %%
Ngaundere2.head(5)
# Out:
#         Cluster T number      IHS ID                    Site Name GE N°  \
# 0  Ngaoundere 2    T0805  IHS_NGD_042             TELLO [ T0805 ]  GE_1
# 1  Ngaoundere 2    T1081  IHS_NGD_040        TOURNINGAL [ T1081 ]  GE_1
# 2  Ngaoundere 2    T1080  IHS_NGD_034             LAORE [ T1080 ]  GE_1
# 3  Ngaoundere 2    T1080  IHS_NGD_034             LAORE [ T1080 ]  GE_1
# 4  Ngaoundere 2  ADM_003  IHS_NGD_027  NGD-UNIVERSITE [ ADM_003 ]  GE_1
#
#    NUMERO DE TICKET D'ACCES AU SITE DATE  EFFECTIVE DE LA VISITE  \
# 0                            250302                   2018-03-24
# 1                            250336                   2018-03-24
# 2                            250445                   2018-03-24
# 3                            249744                   2018-03-23
# 4                            250162                   2018-03-23
#
#   DATE DE VISITE PRECEDENTE  NBRE DE JOUR     TYPE DE GROUPE    ...      \
# ...

# %%
import numpy as np
v1=Ngaundere2['QTEFUELPRECEDENTE'].mean();
v2=Ngaundere2['QTEFUELTROUVEE'].mean();
v6=Ngaundere2['QTEFUELAJOUTEE'].mean(); 
v3=Ngaundere2['QTETOTALELAISSEE'].mean();
Ngaundere2['QTEFUELPRECEDENTE'].replace(np.NaN,v1,inplace=True);
Ngaundere2['QTEFUELTROUVEE'].replace(np.NaN,v2,inplace=True);
Ngaundere2['QTEFUELAJOUTEE'].replace(np.NaN,v6,inplace=True);
Ngaundere2['QTETOTALELAISSEE'].replace(np.NaN,v3,inplace=True);

# %%
Ngaundere2.isnull().sum()
# Out:
# Cluster                               0
# T number                              0
# IHS ID                                0
# Site Name                             0
# GE N°                                 0
# NUMERO DE TICKET D'ACCES AU SITE      0
# DATE  EFFECTIVE DE LA VISITE          0
# DATE DE VISITE PRECEDENTE             0
# NBRE DE JOUR                          0
# TYPE DE GROUPE                        0
# Generator 1capacity (KVA)             0
# COMPTEUR HORAIRE ACTUEL GE1           0
# ANCIEN COMPTEUR HORAIRE G1            0
# SERVICE (YES/NO)                    225
# OIL REMOVED                         223
# OIL ADDED                           223
# GEN 1\nAIR FILTER\nReferences       260
# GEN 1\nOIL FILTER\nReferences       236
# GEN 1\nFUEL FILTER\nReferences      231
# GEN 1\nFAN BELT\nReferences         258
# QTEFUELPRECEDENTE                     0
# QTEFUELTROUVEE                        0
# QTEFUELAJOUTEE                        0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn; seaborn.set()

# %%
plt.scatter(Ngaundere2[["NBREHEURESDEFONCTIONNEMENTDG1"]],Ngaundere2[["ConsumptionHIS"]]);
plt.xlabel('NBREHEURESDEFONCTIONNEMENTDG1')
plt.ylabel('ConsumptionHIS')

# %%
import numpy as np
plt.scatter(Ngaundere2[["NBREHEURESDEFONCTIONNEMENTDG1"]],np.log(Ngaundere2[["ConsumptionHIS"]]));
plt.xlabel('NBREHEURES DE FONCTIONNEMENTDG1')
plt.ylabel('Consumption HIS')
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log
#   from ipykernel import kernelapp as app

# %%
plt.scatter(np.log(Ngaundere2[["NBREHEURESDEFONCTIONNEMENTDG1"]]),Ngaundere2[["ConsumptionHIS"]]);
plt.xlabel('NBRE HEURES DE FONCTIONNEMENT DG1')
plt.ylabel('Consumption HIS')
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(np.log(Ngaundere2[["NBREHEURESDEFONCTIONNEMENTDG1"]]),np.log(Ngaundere2[["ConsumptionHIS"]]));
plt.xlabel('NBRE HEURES DE FONCTIONNEMENT DG1')
plt.ylabel('Consumption HIS')
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(Ngaundere2[["QTEFUELPRECEDENTE"]],Ngaundere2[["ConsumptionHIS"]]);
plt.xlabel('QTE FUEL PRECEDENTE')
plt.ylabel('Consumption HIS')

# %%
plt.scatter(Ngaundere2[["QTEFUELPRECEDENTE"]],np.log(Ngaundere2[["ConsumptionHIS"]]));
plt.xlabel('QTE FUEL PRECEDENTE')
plt.ylabel('Consumption HIS')
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(np.log(Ngaundere2[["QTEFUELPRECEDENTE"]]),np.log(Ngaundere2[["ConsumptionHIS"]]));
plt.xlabel('QTE FUEL PRECEDENTE')
plt.ylabel('Consumption HIS')
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(Ngaundere2[["QTEFUELTROUVEE"]],Ngaundere2[["ConsumptionHIS"]]);
plt.xlabel("QTE FUEL TROUVEE")
plt.ylabel("Consumption HIS")

# %%
plt.scatter(Ngaundere2[["QTEFUELTROUVEE"]],np.log(Ngaundere2[["ConsumptionHIS"]]));
plt.xlabel("QTE FUEL TROUVEE")
plt.ylabel("Consumption HIS")
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(np.log(Ngaundere2[["QTEFUELTROUVEE"]]),np.log(Ngaundere2[["ConsumptionHIS"]]));
plt.xlabel("QTE FUEL TROUVEE")
plt.ylabel("Consumption HIS")
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(np.log(Ngaundere2[["QTEFUELTROUVEE"]]),Ngaundere2[["ConsumptionHIS"]]);
plt.xlabel("QTE FUEL TROUVEE")
plt.ylabel("Consumption HIS")
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(Ngaundere2[["QTEFUELAJOUTEE"]],Ngaundere2[["ConsumptionHIS"]]);
plt.xlabel("QTE FUEL TROUVEE")
plt.ylabel("Consumption HIS")

# %%
plt.scatter(np.log(Ngaundere2[["QTEFUELAJOUTEE"]]),Ngaundere2[["ConsumptionHIS"]]);
plt.xlabel("QTE FUEL TROUVEE")
plt.ylabel("Consumption HIS")
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(np.log(Ngaundere2[["QTEFUELAJOUTEE"]]),np.log(Ngaundere2[["ConsumptionHIS"]]));
plt.xlabel("QTE FUEL TROUVEE")
plt.ylabel("Consumption HIS")
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
plt.scatter(Ngaundere2[["QTEFUELAJOUTEE"]],np.log(Ngaundere2[["ConsumptionHIS"]]));
plt.xlabel("QTE FUEL TROUVEE")
plt.ylabel("Consumption HIS")
# Out:
# /usr/lib/python3/dist-packages/ipykernel/__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
Ngaundere2_subset = Ngaundere2[['Site Name', 'NBREHEURESDEFONCTIONNEMENTDG1','ConsumptionHIS']]
Ngaundere2_subset.head()
# Out:
#                     Site Name  NBREHEURESDEFONCTIONNEMENTDG1  ConsumptionHIS
# 0             TELLO [ T0805 ]                            215           516.0
# 1        TOURNINGAL [ T1081 ]                             78           156.0
# 2             LAORE [ T1080 ]                             21            42.0
# 3             LAORE [ T1080 ]                            214           428.0
# 4  NGD-UNIVERSITE [ ADM_003 ]                              5            10.0

# %%
Consumption_nbreheure_by_Site=Ngaundere2_subset.set_index('Site Name')
Consumption_nbreheure_by_Site.head()
# Out:
#                             NBREHEURESDEFONCTIONNEMENTDG1  ConsumptionHIS
# Site Name
# TELLO [ T0805 ]                                       215           516.0
# TOURNINGAL [ T1081 ]                                   78           156.0
# LAORE [ T1080 ]                                        21            42.0
# LAORE [ T1080 ]                                       214           428.0
# NGD-UNIVERSITE [ ADM_003 ]                              5            10.0

# %%
len(Consumption_by_Site["ConsumptionHIS"])
# Out:
# 501

# %%
Consumption_nbreheure_by_Site.head(50).plot(kind='bar', figsize=(20,8))
plt.show()

# %%
Consumption_nbreheure_by_Site.tail(50).plot(kind='bar', figsize=(20,8))
plt.show()

# %%
plt.hist(Consumption_nbreheure_by_Site["ConsumptionHIS"]);

# %%
df=Ngaundere2[['QTEFUELPRECEDENTE','QTEFUELTROUVEE','QTEFUELAJOUTEE','QTETOTALELAISSEE','NBREHEURESDEFONCTIONNEMENTDG1','CONSOMMATIONHORAIREDEFUELDG1','ConsumptionHIS']]
import statsmodels.formula.api as msf
df.isnull().sum()
# Out:
# QTEFUELPRECEDENTE                0
# QTEFUELTROUVEE                   0
# QTEFUELAJOUTEE                   0
# QTETOTALELAISSEE                 0
# NBREHEURESDEFONCTIONNEMENTDG1    0
# CONSOMMATIONHORAIREDEFUELDG1     0
# ConsumptionHIS                   0
# dtype: int64

# %%
reg=msf.ols('ConsumptionHIS ~ QTEFUELPRECEDENTE + QTEFUELTROUVEE + QTEFUELAJOUTEE + QTETOTALELAISSEE + NBREHEURESDEFONCTIONNEMENTDG1 + CONSOMMATIONHORAIREDEFUELDG1', data = df)
res = reg.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         ConsumptionHIS   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     1835.
# Date:                Fri, 18 May 2018   Prob (F-statistic):               0.00
# Time:                        15:12:44   Log-Likelihood:                -2598.6
# No. Observations:                 501   AIC:                             5211.
# Df Residuals:                     494   BIC:                             5241.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                      -230.6087     11.151    -20.681      0.000    -252.518    -208.700
# ...

# %%
Ngaundere2.head(18).boxplot('ConsumptionHIS',by='Site Name',grid=True,figsize=(50,8))

# %%
Ngaundere2.tail(18).boxplot('ConsumptionHIS',by='Site Name',grid=True,figsize=(50,8))

# %%
Ngaundere2['ConsumptionHIS'].mean()
# Out:
# 169.39261477045906
